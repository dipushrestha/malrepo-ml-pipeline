# %% [markdown]
# # Results Analysis
#
# Analyze model predictions and errors.

# %%
import json
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Load evaluation results
results_path = Path('experiments/eval_results.json')
if results_path.exists():
    results = json.loads(results_path.read_text())
    print('Evaluation Metrics:')
    for k, v in results.items():
        print(f'  {k}: {v}')
else:
    print('No results found. Run evaluation first.')

# %%
# Per-class performance analysis
from src.evaluation.metrics import confusion_matrix, compute_all_metrics

# Would load predictions from saved file in practice
print('Run scripts/evaluate.py first to generate predictions.')
